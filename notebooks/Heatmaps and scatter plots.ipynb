# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Given data sorted along age

# %%
filepath = "./heart.csv"
heart_df = pd.read_csv(filepath)
heart_df.dropna(inplace = True)
heart_df.sort_values(by = "age", inplace = True)
display(heart_df)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72    29    1   1       130   204    0        0      202      0      0.0
# 58    34    1   3       118   182    0        0      174      0      0.0
# 125   34    0   1       118   210    0        1      192      0      0.7
# 239   35    1   0       126   282    0        0      156      1      0.0
# 65    35    0   0       138   183    0        1      182      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 60    71    0   2       110   265    1        0      130      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 238   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 72       2   0     2       1
# 58       2   0     2       1
# ...

# %% [markdown]
# # Heatmap

# %%
# display(heart_df.corr())
ax = sns.heatmap(heart_df.corr())

# %% [markdown]
# # Scatter plots for different parameters and their relation with age

# %%
print(heart_df.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize = (5, 3))
sns.scatterplot(
    data=heart_df, x="age", y="cp", 
    legend="full"  
)
# Out:
# <AxesSubplot:xlabel='age', ylabel='cp'>

# %%
sns.scatterplot(
    data=heart_df, x="age", y="trestbps", 
    legend="full" 
)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %%
sns.scatterplot(
    data=heart_df, x="age", y="chol", 
    legend="full"
)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
sns.scatterplot(
    data=heart_df, x="age", y="fbs", 
    legend="full"
)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fbs'>

# %%
print(heart_df.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
fig, axes = plt.subplots(4, 3, figsize = (15, 15))
plt.subplots_adjust(
    hspace = 0.5
)
for ax, col_name in zip(axes.flatten(), heart_df.columns.values[2:]):
    sns.scatterplot(data = heart_df, x = "age", y = col_name, ax = ax)
    ax.set_title(col_name)
